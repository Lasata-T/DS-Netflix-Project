# %%
# using Linear Regression from sklearn

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
gdp_data1 = pd.read_csv('gdp_final.csv').drop('Unnamed: 0', axis = 1)
gdp_data1
# Out:
#     Country Code                 Country Name      2020_GDP  \
# 0            ABW                        Aruba           NaN
# 1            AFE  Africa Eastern and Southern  9.207923e+11
# 2            AFG                  Afghanistan  2.011614e+10
# 3            AFW   Africa Western and Central  7.845876e+11
# 4            AGO                       Angola  5.837598e+10
# ..           ...                          ...           ...
# 260          XKX                       Kosovo  7.716925e+09
# 261          YEM                  Yemen, Rep.           NaN
# 262          ZAF                 South Africa  3.354421e+11
# 263          ZMB                       Zambia  1.811063e+10
# 264          ZWE                     Zimbabwe  1.805117e+10
#
#                          Region          IncomeGroup
# 0     Latin America & Caribbean          High income
# 1                           NaN                  NaN
# 2                    South Asia           Low income
# ...

# %%
gdp_data2 = gdp_data1.dropna()
gdp_data2
# Out:
#     Country Code          Country Name      2020_GDP  \
# 2            AFG           Afghanistan  2.011614e+10
# 4            AGO                Angola  5.837598e+10
# 5            ALB               Albania  1.488763e+10
# 8            ARE  United Arab Emirates  3.588688e+11
# 9            ARG             Argentina  3.892881e+11
# ..           ...                   ...           ...
# 259          WSM                 Samoa  8.071008e+08
# 260          XKX                Kosovo  7.716925e+09
# 262          ZAF          South Africa  3.354421e+11
# 263          ZMB                Zambia  1.811063e+10
# 264          ZWE              Zimbabwe  1.805117e+10
#
#                          Region          IncomeGroup
# 2                    South Asia           Low income
# 4            Sub-Saharan Africa  Lower middle income
# 5         Europe & Central Asia  Upper middle income
# 8    Middle East & North Africa          High income
# 9     Latin America & Caribbean  Upper middle income
# ...

# %%
region = pd.DataFrame(gdp_data2['Region'])
region
# Out:
#                          Region
# 2                    South Asia
# 4            Sub-Saharan Africa
# 5         Europe & Central Asia
# 8    Middle East & North Africa
# 9     Latin America & Caribbean
# ..                          ...
# 259         East Asia & Pacific
# 260       Europe & Central Asia
# 262          Sub-Saharan Africa
# 263          Sub-Saharan Africa
# 264          Sub-Saharan Africa
#
# [194 rows x 1 columns]

# %%
unique_regions = gdp_data2['Region'].unique()
unique_regions
# Out:
# array(['South Asia', 'Sub-Saharan Africa', 'Europe & Central Asia',
#        'Middle East & North Africa', 'Latin America & Caribbean',
#        'East Asia & Pacific', 'North America'], dtype=object)

# %%
# 1 - South Asia 

# 2 - Sub-Saharan Africa 

# 3 - Europe & Central Asia 

# 4 - Middle East & North Africa

# 5 - Latin American & Caribbean

# 6 - East Asia & Pacific

# 7 - North America

# %%
# set numbers to each region
# make column based on that

# %%
numbered_regions = gdp_data2.insert(5, 'Numbered Regions', 0) # zero is placeholder
gdp_data2['Numbered Regions'] # do NOT just insert and put placeholder 
# try to add correct values right as you make the new column
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-eb8986c208fd> in <module>
# ----> 1 numbered_regions = gdp_data2.insert(5, 'Numbered Regions', 0) # zero is placeholder
#       2 gdp_data2['Numbered Regions']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# -> 3496         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3497
#    3498     def assign(self, **kwargs) -> "DataFrame":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
# ...

# %%
for i in gdp_data2['Region']:
    if i == ('South Asia'):
        gdp_data2['Numbered Regions'].replace(0, 1)
    
    if i == ('Sub-Saharan Africa'):
        gdp_data2['Numbered Regions'].replace(0, 2)
    
    if i == ('Europe & Central Asia'):
        gdp_data2['Numbered Regions'].replace(0, 3)
    
    if i == ('Middle East & North Africa'):
        gdp_data2['Numbered Regions'].replace(0, 4)
        
    if i == ('Latin America & Caribbean'):
        gdp_data2['Numbered Regions'].replace(0, 5)
    
    if i == ('East Asia & Pacific'):
        gdp_data2['Numbered Regions'].replace(0, 6)
    
    if i == ('North America'):
        gdp_data2['Numbered Regions'].replace(0, 7)

# %%
gdp_data2
# Out:
#     Country Code          Country Name      2020_GDP  \
# 2            AFG           Afghanistan  2.011614e+10
# 4            AGO                Angola  5.837598e+10
# 5            ALB               Albania  1.488763e+10
# 8            ARE  United Arab Emirates  3.588688e+11
# 9            ARG             Argentina  3.892881e+11
# ..           ...                   ...           ...
# 259          WSM                 Samoa  8.071008e+08
# 260          XKX                Kosovo  7.716925e+09
# 262          ZAF          South Africa  3.354421e+11
# 263          ZMB                Zambia  1.811063e+10
# 264          ZWE              Zimbabwe  1.805117e+10
#
#                          Region          IncomeGroup  Numbered Regions
# 2                    South Asia           Low income                 0
# 4            Sub-Saharan Africa  Lower middle income                 0
# 5         Europe & Central Asia  Upper middle income                 0
# ...

# %%
num_regions = gdp_data2['Numbered Regions']
# num_regions

# %%
gdp_2020 = gdp_data2['2020_GDP']
# gdp_2020

# %%
lin_reg = LinearRegression().fit(num_regions, gdp_2020)

# %%
# if not lin reg, bar graph to show differences in GDP between region?

# then differences in income within regions? i.e. how many people are in each income group for each region
